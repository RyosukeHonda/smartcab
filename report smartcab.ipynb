# %%
import pandas as pd
df=pd.read_csv('random.csv')

# %%
len(df[df['Deadline']==0])
# Out:
# 80

# %%
df.tail()
# Out:
#       Unnamed: 0  Time  Reward  Deadline  Episode
# 2989        2989    16    -6.0         4      100
# 2990        2990    17    -7.0         3      100
# 2991        2991    18    -7.0         2      100
# 2992        2992    19    -7.5         1      100
# 2993        2993    20    -8.0         0      100

# %%
success_rate=(100.0-len(df[df['Deadline']==0]))/100.0
success_rate
# Out:
# 0.2

# %%
num=df[df["Time"]==0]["Unnamed: 0"]
num
# Out:
# 0          0
# 13        13
# 44        44
# 90        90
# 136      136
# 167      167
# 198      198
# 219      219
# 250      250
# 271      271
# 302      302
# 343      343
# 389      389
# 420      420
# 456      456
# 473      473
# 504      504
# 525      525
# 551      551
# 598      598
# 624      624
# 680      680
# 711      711
# 719      719
# 770      770
# 801      801
# 814      814
# 845      845
# 876      876
# 922      922
#         ...
# 2160    2160
# 2191    2191
# 2196    2196
# 2234    2234
# 2255    2255
# 2286    2286
# 2342    2342
# 2373    2373
# 2414    2414
# 2440    2440
# 2476    2476
# 2497    2497
# 2528    2528
# 2554    2554
# 2590    2590
# 2621    2621
# 2642    2642
# 2648    2648
# 2679    2679
# 2715    2715
# 2736    2736
# 2757    2757
# 2793    2793
# 2819    2819
# 2845    2845
# 2871    2871
# 2892    2892
# 2923    2923
# 2942    2942
# 2973    2973
# Name: Unnamed: 0, dtype: int64

# %%
df_totalreward=df.ix[num-1]

# %%
df_total_reward=df_totalreward.drop(df_totalreward.index[0])

# %%
df_total_reward
# Out:
#       Unnamed: 0  Time  Reward  Deadline  Episode
# 12          12.0  12.0    16.5       8.0      1.0
# 43          43.0  30.0    -1.5       0.0      2.0
# 89          89.0  45.0     1.0       0.0      3.0
# 135        135.0  45.0     4.0       0.0      4.0
# 166        166.0  30.0    -2.0       0.0      5.0
# 197        197.0  30.0    -4.0       0.0      6.0
# 218        218.0  20.0     3.0       0.0      7.0
# 249        249.0  30.0    -1.0       0.0      8.0
# 270        270.0  20.0     6.5       0.0      9.0
# 301        301.0  30.0    21.0       5.0     10.0
# 342        342.0  40.0    -5.0       0.0     11.0
# 388        388.0  45.0     9.5       0.0     12.0
# 419        419.0  30.0    -6.0       0.0     13.0
# 455        455.0  35.0    -9.5       0.0     14.0
# 472        472.0  16.0    12.5       4.0     15.0
# 503        503.0  30.0     9.0       0.0     16.0
# 524        524.0  20.0    -1.0       0.0     17.0
# 550        550.0  25.0   -10.0       0.0     18.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df_total_reward["Episode"],df_total_reward["Reward"])
plt.xlabel("No.Episode")
plt.ylabel("Total Reward")

# %%
df[df['Deadline']==0]
# Out:
#       Unnamed: 0  Time  Reward  Deadline  Episode
# 43            43    30    -1.5         0        2
# 89            89    45     1.0         0        3
# 135          135    45     4.0         0        4
# 166          166    30    -2.0         0        5
# 197          197    30    -4.0         0        6
# 218          218    20     3.0         0        7
# 249          249    30    -1.0         0        8
# 270          270    20     6.5         0        9
# 342          342    40    -5.0         0       11
# 388          388    45     9.5         0       12
# 419          419    30    -6.0         0       13
# 455          455    35    -9.5         0       14
# 503          503    30     9.0         0       16
# 524          524    20    -1.0         0       17
# 550          550    25   -10.0         0       18
# 623          623    25   -11.0         0       20
# 679          679    55     0.5         0       21
# 710          710    30    -0.5         0       22
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  Time  Reward  Deadline  Episode
# 2989        2989    16    -6.0         4      100
# 2990        2990    17    -7.0         3      100
# 2991        2991    18    -7.0         2      100
# 2992        2992    19    -7.5         1      100
# 2993        2993    20    -8.0         0      100

# %%
time0=df[df["Time"]==0]["Unnamed: 0"]

# %%
time0.head()
# Out:
# 0        0
# 13      13
# 44      44
# 90      90
# 136    136
# Name: Unnamed: 0, dtype: int64

# %%
df_end_of_episode=df.ix[time0-1]

# %%
df_end_of_episode.head()
# Out:
#       Unnamed: 0  Time  Reward  Deadline  Episode
# -1           NaN   NaN     NaN       NaN      NaN
#  12         12.0  12.0    16.5       8.0      1.0
#  43         43.0  30.0    -1.5       0.0      2.0
#  89         89.0  45.0     1.0       0.0      3.0
#  135       135.0  45.0     4.0       0.0      4.0

# %%
df_end_of_episode=df_end_of_episode.drop(df_end_of_episode.index[0])

# %%
df_end_of_episode.tail()
# Out:
#       Unnamed: 0  Time  Reward  Deadline  Episode
# 2870      2870.0  25.0    -3.5       0.0     95.0
# 2891      2891.0  20.0    -2.5       0.0     96.0
# 2922      2922.0  30.0    -4.5       0.0     97.0
# 2941      2941.0  18.0    14.0      12.0     98.0
# 2972      2972.0  30.0    -9.0       0.0     99.0

# %%
plt.plot(df_end_of_episode['Episode'],df_end_of_episode['Reward'])
plt.xlabel("No.Episode")
plt.ylabel("Total Reward")

# %%
df.tail(1)
# Out:
#       Unnamed: 0  Time  Reward  Deadline  Episode
# 2993        2993    20    -8.0         0      100

# %%
total_reward=pd.merge(df_end_of_episode,df.tail(1),how='outer')

# %%
plt.plot(total_reward['Episode'],total_reward['Reward'])
plt.xlabel("No.Episode")
plt.ylabel("Total Reward")

# %%
total_reward['Reward'].cumsum().tail()
# Out:
# 95    19.0
# 96    14.5
# 97    28.5
# 98    19.5
# 99    11.5
# Name: Reward, dtype: float64

# %%
total_reward['Reward'].tail()
# Out:
# 95    -2.5
# 96    -4.5
# 97    14.0
# 98    -9.0
# 99    -8.0
# Name: Reward, dtype: float64

# %%
import  pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df100=pd.read_csv('report.csv')
def success_rate(df):
    return (100.0-len(df[df["Deadline"]==0]))/100.0
def total_reward(df):
    time0=df[df['Time']==0]["Unnamed: 0"]
    df_time0=df.ix[time0-1]
    df_time0=df_time0.drop(df_time0.index[0])
    total_reward=pd.merge(df_time0,df.tail(1),how='outer')
    plt.plot(total_reward['Episode'],total_reward['Reward'])
    plt.xlabel('No.Episode')
    plt.ylabel('Total Reward')
   
    return total_reward['Reward'].cumsum().tail(1)

# %%
df_constant=pd.read_csv('constant.csv')

# %%
success_rate(df_constant)
# Out:
# 0.72

# %%
total_reward(df_constant)
# Out:
# 99    2195.5
# Name: Reward, dtype: float64

# %%
total_reward(df100)
# Out:
# 99    2097.5
# Name: Reward, dtype: float64

# %%
df_random=pd.read_csv('random.csv')
total_reward(df_random)
# Out:
# 99    11.5
# Name: Reward, dtype: float64

# %%
success_rate(df_random)
# Out:
# 0.2

# %%
df_better=pd.read_csv('better.csv')
total_reward(df_better)
# Out:
# 99    2099.0
# Name: Reward, dtype: float64

# %%
success_rate(df_better)
# Out:
# 0.86

# %%
df_gamma_con=pd.read_csv('gamma_con.csv')
total_reward(df_gamma_con)
# Out:
# 99    2580.5
# Name: Reward, dtype: float64

# %%
success_rate(df_gamma_con)
# Out:
# 0.86

# %%
df_gamma_con
# Out:
#       Unnamed: 0  Time  Reward  Deadline  Episode
# 0              0     0    -0.5        20        1
# 1              1     1    -0.5        19        1
# 2              2     2    -0.5        18        1
# 3              3     3    -1.5        17        1
# 4              4     4     0.5        16        1
# 5              5     5    -0.5        15        1
# 6              6     6     1.5        14        1
# 7              7     7     1.5        13        1
# 8              8     8     1.0        12        1
# 9              9     9     0.5        11        1
# 10            10    10     2.5        10        1
# 11            11    11     4.5         9        1
# 12            12    12     3.5         8        1
# 13            13    13     2.5         7        1
# 14            14    14     2.5         6        1
# 15            15    15     2.0         5        1
# 16            16    16     4.0         4        1
# 17            17    17     3.5         3        1
# ...
